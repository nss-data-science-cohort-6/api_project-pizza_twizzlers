# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd

# %%
incident_reported = "https://data.nashville.gov/resource/2u6v-ujjs.json?$where=incident_reported between '2022-01-01T00:00:00' and '2022-09-30T23:59:59'"
response = requests.get(incident_reported)

# %%
response.text
# Out:
# '[{"primary_key":"20210659479_11","incident_number":"20210659479","report_type":"D","report_type_description":"DISPATCHED","incident_status_code":"U","incident_status_description":"UNFOUNDED","investigation_status":"Closed","incident_occurred":"2021-12-31T23:05:00.000","incident_reported":"2022-01-01T00:00:00.000","incident_location":"507 507","latitude":"36.076","longitude":"-86.645","zip_code":"37013","location_code":"90","location_description":"APARTMENT","offense_number":"1","offense_nibrs":"740","offense_description":"POLICE INQUIRY","weapon_primary":"17","weapon_description":"NONE","victim_number":"1","domestic_related":true,"victim_type":"I","victim_description":"INDIVIDUAL (18 AND OVER)","victim_gender":"F","victim_race":"B","victim_ethnicity":"Non-Hispanic","victim_county_resident":"RESIDENT","mapped_location":{"type":"Point","coordinates":[-86.645,36.076]}}\n,{"primary_key":"20210659403_11","incident_number":"20210659403","report_type":"D","report_type_description":"DISPATCHED","incident_status_code":"U","incident_status_description":"UNFOUNDED","investigation_status":"Closed","incident_occurred":"2021-12-31T16:44:00.000","incident_reported":"2022-01-01T00:09:00.000","incident_location":"610 610","latitude":"36.142","longitude":"-86.74","zip_code":"37210","rpa":"8217","zone":"513","location_code":"11","location_description":"GOVERNMENT, PUBLIC BUILDING","offense_number":"1","offense_nibrs":"740","offense_description":"POLICE INQUIRY","weapon_primary":"17","weapon_description":"NONE","victim_number":"1","domestic_related":true,"victim_type":"I","victim_description":"INDIVIDUAL (18 AND OVER)","victim_gender":"F","victim_race":"W","victim_ethnicity":"Non-Hispanic","mapped_location":{"type":"Point","coordinates":[-86.74,36.142]}}\n,{"primary_key":"20210659497_11","incident_number":"20210659497","report_type":"D","report_type_description":"DISPATCHED","incident_status_code":"U","incident_status_description":"UNFOUNDED","investigation_status":"Closed","incident_occurred":"2021-12-31T07:00:00.000","incident_reported":"2022-01-01T00:16:00.000","incident_location":"1901 1901","latitude":"36.166","longitude":"-86.597","zip_code":"37076","rpa":"9543","zone":"523","location_code":"22","location_description":"RESIDENCE, HOME","offense_number":"1","offense_nibrs":"740","offense_description":"POLICE INQUIRY","weapon_primary":"17","weapon_description":"NONE","victim_number":"1","domestic_related":true,"victim_type":"I","victim_description":"INDIVIDUAL (18 AND OVER)","victim_gender":"F","victim_race":"B","victim_ethnicity":"Non-Hispanic","victim_county_resident":"RESIDENT","mapped_location":{"type":"Point","coordinates":[-86.597,36.166]}}\n,{"primary_key":"20220000036_11","incident_number":"20220000036","report_type":"S","report_type_description":"SUSPECT","incident_status_code":"O","incident_status_description":"OPEN","investigation_status":"Open","incident_occurred":"2021-12-31T22:28:00.000","incident_reported":"2022-01-01T00:19:00.000","incident_location":"8TH AVE S","latitude":"36.16","longitude":"-86.78","rpa":"4075","zone":"421","location_code":"20","location_description":"PARKING LOT, GARAGE","offense_number":"1","offense_nibrs":"290","offense_description":"DAMAGE PROP - PUBLIC","weapon_primary":"16","weapon_description":"Unarmed","victim_number":"1","domestic_related":false,"victim_type":"G","victim_description":"GOVERNMENT","mapped_location":{"type":"Point","coordinates":[-86.78,36.16]}}\n,{"primary_key":"20210659488_11","incident_number":"20210659488","report_type":"S","report_type_description":"SUSPECT","incident_status_code":"U","incident_status_description":"UNFOUNDED","investigation_status":"Closed","incident_occurred":"2021-12-31T22:00:00.000","incident_reported":"2022-01-01T00:36:00.000","incident_location":"1514 1514","latitude":"36.153","longitude":"-86.789","zip_code":"37203","rpa":"5701","zone":"811","location_code":"13","location_description":"HIGHWAY, ROAD, ALLEY","offense_number":"1","offense_nibrs":"715","offe ...

# %%
res = response.json()
res
# Out:
# [{'primary_key': '20210659479_11',
#   'incident_number': '20210659479',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T23:05:00.000',
#   'incident_reported': '2022-01-01T00:00:00.000',
#   'incident_location': '507 507',
#   'latitude': '36.076',
#   'longitude': '-86.645',
#   'zip_code': '37013',
#   'location_code': '90',
#   'location_description': 'APARTMENT',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.645, 36.076]}},
#  {'primary_key': '20210659403_11',
#   'incident_number': '20210659403',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T16:44:00.000',
#   'incident_reported': '2022-01-01T00:09:00.000',
#   'incident_location': '610 610',
#   'latitude': '36.142',
#   'longitude': '-86.74',
#   'zip_code': '37210',
#   'rpa': '8217',
#   'zone': '513',
#   'location_code': '11',
#   'location_description': 'GOVERNMENT, PUBLIC BUILDING',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.74, 36.142]}},
#  {'primary_key': '20210659497_11',
#   'incident_number': '20210659497',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T07:00:00.000',
#   'incident_reported': '2022-01-01T00:16:00.000',
#   'incident_location': '1901 1901',
#   'latitude': '36.166',
#   'longitude': '-86.597',
#   'zip_code': '37076',
#   'rpa': '9543',
#   'zone': '523',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.597, 36.166]}},
#  {'primary_key': '20220000036_11',
#   'incident_number': '20220000036',
#   'report_type': 'S',
#   'report_type_description': 'SUSPECT',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2021-12-31T22:28:00.000',
#   'incident_reported': '2022-01-01T00:19:00.000',
#   'incident_location': '8TH AVE S',
#   'latitude': '36.16',
#   'longitude': '-86.78',
#   'rpa': '4075',
#   'zone': '421',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '290',
#   'offense_description': 'DAMAGE PROP - PUBLIC',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'G',
#   'victim_description': 'GOVERNMENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.78, 36.16]}},
#  {'primary_key': '20210659488_11',
#   'incident_number': '20210659488',
#   'report_type': 'S',
#   'report_type_description': 'SUSPECT',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T22:00:00.000',
#   'incident_reported': '2022-01-01T00:36:00.000',
#   'incident_location': '1514 1514',
#   'latitude': '36.153',
#   'longitude': '-86.789',
#   'zip_code': '37203',
#   'rpa': '5701',
#   'zone': '811',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '1',
#   'offense_nibrs': '715',
#   'offense_description': 'FOUND PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'U',
#   'victim_description': 'UNKNOWN',
#   'victim_gender': 'U',
#   'victim_race': 'U',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.789, 36.153]}},
#  {'primary_key': '20220000029_11',
#   'incident_number': '20220000029',
#   'report_type': 'S',
#   'report_type_description': 'SUSPECT',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2021-12-31T23:30:00.000',
#   'incident_reported': '2022-01-01T00:46:00.000',
#   'incident_location': 'BROADWAY',
#   'latitude': '36.16',
#   'longitude': '-86.78',
#   'rpa': '4091',
#   'zone': '421',
#   'location_code': '3',
#   'location_description': 'BAR, NIGHT CLUB',
#   'offense_number': '1',
#   'offense_nibrs': '13B',
#   'offense_description': 'ASSAULT- OFFENSIVE OR PROVOCATIVE CONTACT',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.78, 36.16]}},
#  {'primary_key': '20210659509_11',
#   'incident_number': '20210659509',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2021-12-31T23:50:00.000',
#   'incident_reported': '2022-01-01T00:55:00.000',
#   'incident_location': 'SEIFRIED ST',
#   'latitude': '36.18',
#   'longitude': '-86.81',
#   'rpa': '4417',
#   'zone': '621',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '35B',
#   'offense_description': 'DRUG PARAPHERNALIA- UNLAWFUL USE',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'S',
#   'victim_description': 'SOCIETY',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.81, 36.18]}},
#  {'primary_key': '20220000042_11',
#   'incident_number': '20220000042',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:20:00.000',
#   'incident_reported': '2022-01-01T00:57:00.000',
#   'incident_location': 'IRELAND ST',
#   'latitude': '36.17',
#   'longitude': '-86.8',
#   'rpa': '5427',
#   'zone': '613',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '13A',
#   'offense_description': 'AGGRAV ASSLT - NONFAMILY-GUN',
#   'weapon_primary': '01',
#   'weapon_description': 'HANDGUN',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.8, 36.17]}},
#  {'primary_key': '20220000042_22',
#   'incident_number': '20220000042',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:20:00.000',
#   'incident_reported': '2022-01-01T00:57:00.000',
#   'incident_location': 'IRELAND ST',
#   'latitude': '36.17',
#   'longitude': '-86.8',
#   'rpa': '5427',
#   'zone': '613',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '2',
#   'offense_nibrs': '520',
#   'offense_description': 'WEAPON OFFENSE, CRIMINAL ATTEMPT',
#   'weapon_primary': '01',
#   'weapon_description': 'HANDGUN',
#   'victim_number': '2',
#   'domestic_related': False,
#   'victim_type': 'S',
#   'victim_description': 'SOCIETY',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.8, 36.17]}},
#  {'primary_key': '20220000072_11',
#   'incident_number': '20220000072',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T21:30:00.000',
#   'incident_reported': '2022-01-01T01:01:00.000',
#   'incident_location': '1314 1314',
#   'latitude': '36.137',
#   'longitude': '-86.638',
#   'zip_code': '37214',
#   'rpa': '8991',
#   'zone': '533',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.638, 36.137]}},
#  {'primary_key': '20220000070_11',
#   'incident_number': '20220000070',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:36:00.000',
#   'incident_reported': '2022-01-01T01:11:00.000',
#   'incident_location': '144 144',
#   'latitude': '36.214',
#   'longitude': '-86.759',
#   'zip_code': '37207',
#   'rpa': '1831',
#   'zone': '223',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '13A',
#   'offense_description': 'Assault, Aggravated - Deadly Weapon - Int/Kn',
#   'weapon_primary': '01',
#   'weapon_description': 'HANDGUN',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.759, 36.214]}},
#  {'primary_key': '20220000070_23',
#   'incident_number': '20220000070',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:36:00.000',
#   'incident_reported': '2022-01-01T01:11:00.000',
#   'incident_location': '144 144',
#   'latitude': '36.214',
#   'longitude': '-86.759',
#   'zip_code': '37207',
#   'rpa': '1831',
#   'zone': '223',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '2',
#   'offense_nibrs': '520',
#   'offense_description': 'WEAPON OFFENSE, CRIMINAL ATTEMPT',
#   'weapon_primary': '01',
#   'weapon_description': 'HANDGUN',
#   'victim_number': '3',
#   'domestic_related': False,
#   'victim_type': 'S',
#   'victim_description': 'SOCIETY',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.759, 36.214]}},
#  {'primary_key': '20220000070_32',
#   'incident_number': '20220000070',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:36:00.000',
#   'incident_reported': '2022-01-01T01:11:00.000',
#   'incident_location': '144 144',
#   'latitude': '36.214',
#   'longitude': '-86.759',
#   'zip_code': '37207',
#   'rpa': '1831',
#   'zone': '223',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '3',
#   'offense_nibrs': '290',
#   'offense_description': 'DAMAGE PROP - PRIVATE',
#   'weapon_primary': '01',
#   'weapon_description': 'HANDGUN',
#   'victim_number': '2',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.759, 36.214]}},
#  {'primary_key': '20220000070_31',
#   'incident_number': '20220000070',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:36:00.000',
#   'incident_reported': '2022-01-01T01:11:00.000',
#   'incident_location': '144 144',
#   'latitude': '36.214',
#   'longitude': '-86.759',
#   'zip_code': '37207',
#   'rpa': '1831',
#   'zone': '223',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '3',
#   'offense_nibrs': '290',
#   'offense_description': 'DAMAGE PROP - PRIVATE',
#   'weapon_primary': '01',
#   'weapon_description': 'HANDGUN',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.759, 36.214]}},
#  {'primary_key': '20220000070_12',
#   'incident_number': '20220000070',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:36:00.000',
#   'incident_reported': '2022-01-01T01:11:00.000',
#   'incident_location': '144 144',
#   'latitude': '36.214',
#   'longitude': '-86.759',
#   'zip_code': '37207',
#   'rpa': '1831',
#   'zone': '223',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '13A',
#   'offense_description': 'Assault, Aggravated - Deadly Weapon - Int/Kn',
#   'weapon_primary': '01',
#   'weapon_description': 'HANDGUN',
#   'victim_number': '2',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.759, 36.214]}},
#  {'primary_key': '20220000101_11',
#   'incident_number': '20220000101',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:54:00.000',
#   'incident_reported': '2022-01-01T01:12:00.000',
#   'incident_location': '9TH AVE N',
#   'latitude': '36.19',
#   'longitude': '-86.8',
#   'rpa': '4445',
#   'zone': '611',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '290',
#   'offense_description': 'DAMAGE PROP - PRIVATE',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.8, 36.19]}},
#  {'primary_key': '20210659382_21',
#   'incident_number': '20210659382',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'A',
#   'incident_status_description': 'CLEARED BY ARREST',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T22:30:00.000',
#   'incident_reported': '2022-01-01T01:13:00.000',
#   'incident_location': '2901 2901',
#   'latitude': '36.168',
#   'longitude': '-86.822',
#   'zip_code': '37209',
#   'rpa': '4521',
#   'zone': '621',
#   'location_code': '90',
#   'location_description': 'APARTMENT',
#   'offense_number': '2',
#   'offense_nibrs': '23D',
#   'offense_description': 'LARC - FROM BLDG',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.822, 36.168]}},
#  {'primary_key': '20210659382_11',
#   'incident_number': '20210659382',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'A',
#   'incident_status_description': 'CLEARED BY ARREST',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T22:30:00.000',
#   'incident_reported': '2022-01-01T01:13:00.000',
#   'incident_location': '2901 2901',
#   'latitude': '36.168',
#   'longitude': '-86.822',
#   'zip_code': '37209',
#   'rpa': '4521',
#   'zone': '621',
#   'location_code': '90',
#   'location_description': 'APARTMENT',
#   'offense_number': '1',
#   'offense_nibrs': '13B',
#   'offense_description': 'SIMPLE ASSLT',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.822, 36.168]}},
#  {'primary_key': '20220000078_11',
#   'incident_number': '20220000078',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T23:50:00.000',
#   'incident_reported': '2022-01-01T01:24:00.000',
#   'incident_location': '333 333',
#   'latitude': '36.269',
#   'longitude': '-86.683',
#   'zip_code': '37115',
#   'rpa': '1713',
#   'zone': '715',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '13B',
#   'offense_description': 'SIMPLE ASSLT',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.683, 36.269]}},
#  {'primary_key': '20220000078_12',
#   'incident_number': '20220000078',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T23:50:00.000',
#   'incident_reported': '2022-01-01T01:24:00.000',
#   'incident_location': '333 333',
#   'latitude': '36.269',
#   'longitude': '-86.683',
#   'zip_code': '37115',
#   'rpa': '1713',
#   'zone': '715',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '13B',
#   'offense_description': 'SIMPLE ASSLT',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '2',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.683, 36.269]}},
#  {'primary_key': '20220000055_11',
#   'incident_number': '20220000055',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T23:46:00.000',
#   'incident_reported': '2022-01-01T01:25:00.000',
#   'incident_location': '814 814',
#   'latitude': '36.09',
#   'longitude': '-86.643',
#   'zip_code': '37217',
#   'rpa': '8935',
#   'zone': '535',
#   'location_code': '90',
#   'location_description': 'APARTMENT',
#   'offense_number': '1',
#   'offense_nibrs': '810',
#   'offense_description': 'LOST PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.643, 36.09]}},
#  {'primary_key': '20220000060_11',
#   'incident_number': '20220000060',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T01:00:00.000',
#   'incident_reported': '2022-01-01T01:28:00.000',
#   'incident_location': 'BROADWAY',
#   'latitude': '36.16',
#   'longitude': '-86.78',
#   'rpa': '4091',
#   'zone': '421',
#   'location_code': '23',
#   'location_description': 'RESTAURANT',
#   'offense_number': '1',
#   'offense_nibrs': '13B',
#   'offense_description': 'SIMPLE ASSLT',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.78, 36.16]}},
#  {'primary_key': '20220000016_11',
#   'incident_number': '20220000016',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'A',
#   'incident_status_description': 'CLEARED BY ARREST',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:05:00.000',
#   'incident_reported': '2022-01-01T01:30:00.000',
#   'incident_location': '1317 1317',
#   'latitude': '36.209',
#   'longitude': '-86.724',
#   'zip_code': '37216',
#   'rpa': '1443',
#   'zone': '215',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '1',
#   'offense_nibrs': '520',
#   'offense_description': 'WEAPON OFFENSE, CRIMINAL ATTEMPT',
#   'weapon_primary': '01',
#   'weapon_description': 'HANDGUN',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'S',
#   'victim_description': 'SOCIETY',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.724, 36.209]}},
#  {'primary_key': '20220000016_21',
#   'incident_number': '20220000016',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'A',
#   'incident_status_description': 'CLEARED BY ARREST',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:05:00.000',
#   'incident_reported': '2022-01-01T01:30:00.000',
#   'incident_location': '1317 1317',
#   'latitude': '36.209',
#   'longitude': '-86.724',
#   'zip_code': '37216',
#   'rpa': '1443',
#   'zone': '215',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '2',
#   'offense_nibrs': '35A',
#   'offense_description': 'MARIJUANA - POSSESS',
#   'weapon_primary': '01',
#   'weapon_description': 'HANDGUN',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'S',
#   'victim_description': 'SOCIETY',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.724, 36.209]}},
#  {'primary_key': '20220000047_11',
#   'incident_number': '20220000047',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T01:35:00.000',
#   'incident_reported': '2022-01-01T01:35:00.000',
#   'incident_location': 'WALLACE RD',
#   'latitude': '36.08',
#   'longitude': '-86.7',
#   'location_code': '90',
#   'location_description': 'APARTMENT',
#   'offense_number': '1',
#   'offense_nibrs': '13C',
#   'offense_description': 'ASSAULT- FEAR OF BODILY INJURY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7, 36.08]}},
#  {'primary_key': '20220000156_11',
#   'incident_number': '20220000156',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T19:30:00.000',
#   'incident_reported': '2022-01-01T01:41:00.000',
#   'incident_location': '2930 2930',
#   'latitude': '36.233',
#   'longitude': '-86.795',
#   'zip_code': '37207',
#   'rpa': '3045',
#   'zone': '633',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.795, 36.233]}},
#  {'primary_key': '20210659414_11',
#   'incident_number': '20210659414',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T22:45:00.000',
#   'incident_reported': '2022-01-01T01:42:00.000',
#   'incident_location': '625 625',
#   'latitude': '36.132',
#   'longitude': '-86.771',
#   'zip_code': '37204',
#   'rpa': '8029',
#   'zone': '817',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '13A',
#   'offense_description': 'Assault, Aggravated - Deadly Weapon - Int/Kn',
#   'weapon_primary': '01',
#   'weapon_description': 'HANDGUN',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.771, 36.132]}},
#  {'primary_key': '20210659414_32',
#   'incident_number': '20210659414',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T22:45:00.000',
#   'incident_reported': '2022-01-01T01:42:00.000',
#   'incident_location': '625 625',
#   'latitude': '36.132',
#   'longitude': '-86.771',
#   'zip_code': '37204',
#   'rpa': '8029',
#   'zone': '817',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '3',
#   'offense_nibrs': '520',
#   'offense_description': 'WEAPON OFFENSE, CRIMINAL ATTEMPT',
#   'weapon_primary': '01',
#   'weapon_description': 'HANDGUN',
#   'victim_number': '2',
#   'domestic_related': False,
#   'victim_type': 'S',
#   'victim_description': 'SOCIETY',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.771, 36.132]}},
#  {'primary_key': '20210659414_21',
#   'incident_number': '20210659414',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T22:45:00.000',
#   'incident_reported': '2022-01-01T01:42:00.000',
#   'incident_location': '625 625',
#   'latitude': '36.132',
#   'longitude': '-86.771',
#   'zip_code': '37204',
#   'rpa': '8029',
#   'zone': '817',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '2',
#   'offense_nibrs': '240',
#   'offense_description': 'VEHICLE THEFT',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.771, 36.132]}},
#  {'primary_key': '20220000096_11',
#   'incident_number': '20220000096',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:35:00.000',
#   'incident_reported': '2022-01-01T01:43:00.000',
#   'incident_location': '270 270',
#   'latitude': '36.201',
#   'longitude': '-86.624',
#   'zip_code': '37076',
#   'rpa': '9615',
#   'zone': '525',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '13C',
#   'offense_description': 'ASSAULT- FEAR OF BODILY INJURY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.624, 36.201]}},
#  {'primary_key': '20220000114_11',
#   'incident_number': '20220000114',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T01:05:00.000',
#   'incident_reported': '2022-01-01T01:43:00.000',
#   'incident_location': '44 44',
#   'latitude': '36.145',
#   'longitude': '-86.674',
#   'zip_code': '37214',
#   'rpa': '9103',
#   'zone': '517',
#   'location_code': '14',
#   'location_description': 'HOTEL, MOTEL, ETC.',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.674, 36.145]}},
#  {'primary_key': '20210659494_11',
#   'incident_number': '20210659494',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T23:40:00.000',
#   'incident_reported': '2022-01-01T01:51:00.000',
#   'incident_location': '329 329',
#   'latitude': '36.161',
#   'longitude': '-86.776',
#   'zip_code': '37201',
#   'rpa': '4093',
#   'zone': '421',
#   'location_code': '3',
#   'location_description': 'BAR, NIGHT CLUB',
#   'offense_number': '1',
#   'offense_nibrs': '13B',
#   'offense_description': 'SIMPLE ASSLT',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.776, 36.161]}},
#  {'primary_key': '20210659494_13',
#   'incident_number': '20210659494',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T23:40:00.000',
#   'incident_reported': '2022-01-01T01:51:00.000',
#   'incident_location': '329 329',
#   'latitude': '36.161',
#   'longitude': '-86.776',
#   'zip_code': '37201',
#   'rpa': '4093',
#   'zone': '421',
#   'location_code': '3',
#   'location_description': 'BAR, NIGHT CLUB',
#   'offense_number': '1',
#   'offense_nibrs': '13B',
#   'offense_description': 'SIMPLE ASSLT',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '3',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.776, 36.161]}},
#  {'primary_key': '20210659494_12',
#   'incident_number': '20210659494',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T23:40:00.000',
#   'incident_reported': '2022-01-01T01:51:00.000',
#   'incident_location': '329 329',
#   'latitude': '36.161',
#   'longitude': '-86.776',
#   'zip_code': '37201',
#   'rpa': '4093',
#   'zone': '421',
#   'location_code': '3',
#   'location_description': 'BAR, NIGHT CLUB',
#   'offense_number': '1',
#   'offense_nibrs': '13B',
#   'offense_description': 'SIMPLE ASSLT',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '2',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.776, 36.161]}},
#  {'primary_key': '20220000176_11',
#   'incident_number': '20220000176',
#   'report_type': 'S',
#   'report_type_description': 'SUSPECT',
#   'incident_status_code': 'P',
#   'incident_status_description': 'PROSECUTION DECLINED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T01:00:00.000',
#   'incident_reported': '2022-01-01T01:58:00.000',
#   'incident_location': '105 105',
#   'latitude': '36.162',
#   'longitude': '-86.774',
#   'zip_code': '37201',
#   'rpa': '4095',
#   'zone': '421',
#   'location_code': '3',
#   'location_description': 'BAR, NIGHT CLUB',
#   'offense_number': '1',
#   'offense_nibrs': '13B',
#   'offense_description': 'ASSAULT- OFFENSIVE OR PROVOCATIVE CONTACT',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'NON RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.774, 36.162]}},
#  {'primary_key': '20210659510_11',
#   'incident_number': '20210659510',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T23:48:00.000',
#   'incident_reported': '2022-01-01T02:07:00.000',
#   'incident_location': '4TH AVE N & BROADWAY',
#   'latitude': '36.161',
#   'longitude': '-86.777',
#   'zip_code': '37219',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'O',
#   'victim_ethnicity': 'Non-Hispanic',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.777, 36.161]}},
#  {'primary_key': '20220000077_11',
#   'incident_number': '20220000077',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:30:00.000',
#   'incident_reported': '2022-01-01T02:08:00.000',
#   'incident_location': 'S GALLATIN PIKE',
#   'latitude': '36.26',
#   'longitude': '-86.71',
#   'rpa': '1783',
#   'zone': '711',
#   'location_code': '8',
#   'location_description': 'DEPARTMENT, DISCOUNT STORE',
#   'offense_number': '1',
#   'offense_nibrs': '13B',
#   'offense_description': 'SIMPLE ASSLT',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.71, 36.26]}},
#  {'primary_key': '20220000113_11',
#   'incident_number': '20220000113',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T00:54:00.000',
#   'incident_reported': '2022-01-01T02:08:00.000',
#   'incident_location': 'EASTLAND AVE',
#   'latitude': '36.18',
#   'longitude': '-86.74',
#   'rpa': '1263',
#   'zone': '213',
#   'location_code': '23',
#   'location_description': 'RESTAURANT',
#   'offense_number': '1',
#   'offense_nibrs': '220',
#   'offense_description': 'BURGLARY (NON HABITATION)',
#   'weapon_primary': '07',
#   'weapon_description': 'CLUB',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.74, 36.18]}},
#  {'primary_key': '20220000026_23',
#   'incident_number': '20220000026',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:15:00.000',
#   'incident_reported': '2022-01-01T02:17:00.000',
#   'incident_location': '3RD AVE N & CHURCH ST',
#   'latitude': '36.164',
#   'longitude': '-86.778',
#   'zip_code': '37201',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '2',
#   'offense_nibrs': '520',
#   'offense_description': 'WEAPON OFFENSE, CRIMINAL ATTEMPT',
#   'weapon_primary': '01',
#   'weapon_description': 'HANDGUN',
#   'victim_number': '3',
#   'domestic_related': False,
#   'victim_type': 'S',
#   'victim_description': 'SOCIETY',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.778, 36.164]}},
#  {'primary_key': '20220000026_11',
#   'incident_number': '20220000026',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:15:00.000',
#   'incident_reported': '2022-01-01T02:17:00.000',
#   'incident_location': '3RD AVE N & CHURCH ST',
#   'latitude': '36.164',
#   'longitude': '-86.778',
#   'zip_code': '37201',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '13A',
#   'offense_description': 'AGGRAV ASSLT - NONFAMILY-GUN',
#   'weapon_primary': '01S',
#   'weapon_description': 'HANDGUN - SEMIAUTOMATIC',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.778, 36.164]}},
#  {'primary_key': '20220000026_12',
#   'incident_number': '20220000026',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-01T00:15:00.000',
#   'incident_reported': '2022-01-01T02:17:00.000',
#   'incident_location': '3RD AVE N & CHURCH ST',
#   'latitude': '36.164',
#   'longitude': '-86.778',
#   'zip_code': '37201',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '13A',
#   'offense_description': 'AGGRAV ASSLT - NONFAMILY-GUN',
#   'weapon_primary': '01S',
#   'weapon_description': 'HANDGUN - SEMIAUTOMATIC',
#   'victim_number': '2',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.778, 36.164]}},
#  {'primary_key': '20220000197_11',
#   'incident_number': '20220000197',
#   'report_type': 'S',
#   'report_type_description': 'SUSPECT',
#   'incident_status_code': 'A',
#   'incident_status_description': 'CLEARED BY ARREST',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T22:00:00.000',
#   'incident_reported': '2022-01-01T02:24:00.000',
#   'incident_location': '419 419',
#   'latitude': '36.161',
#   'longitude': '-86.777',
#   'zip_code': '37203',
#   'rpa': '4091',
#   'zone': '421',
#   'location_code': '3',
#   'location_description': 'BAR, NIGHT CLUB',
#   'offense_number': '1',
#   'offense_nibrs': '26A',
#   'offense_description': 'THEFT OF SERVICES-  $500 OR LESS',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.777, 36.161]}},
#  {'primary_key': '20220000193_11',
#   'incident_number': '20220000193',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T23:30:00.000',
#   'incident_reported': '2022-01-01T02:25:00.000',
#   'incident_location': '3028 3028',
#   'latitude': '36.23',
#   'longitude': '-86.787',
#   'zip_code': '37207',
#   'rpa': '3023',
#   'zone': '633',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '715',
#   'offense_description': 'FOUND PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'U',
#   'victim_description': 'UNKNOWN',
#   'victim_gender': 'U',
#   'victim_race': 'U',
#   'victim_ethnicity': 'Non-Hispanic',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.787, 36.23]}},
#  {'primary_key': '20220000099_11',
#   'incident_number': '20220000099',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T02:27:00.000',
#   'incident_reported': '2022-01-01T02:27:00.000',
#   'incident_location': 'SHELBY AVE',
#   'latitude': '36.17',
#   'longitude': '-86.76',
#   'rpa': '1115',
#   'zone': '211',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.76, 36.17]}},
#  {'primary_key': '20210659447_11',
#   'incident_number': '20210659447',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'A',
#   'incident_status_description': 'CLEARED BY ARREST',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-31T23:08:00.000',
#   'incident_reported': '2022-01-01T02:30:00.000',
#   'incident_location': '4092 4092',
#   'latitude': '36.032',
#   'longitude': '-86.594',
#   'zip_code': '37013',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '13A',
#   'offense_description': 'INTENTIONAL AGGRAVATED ASSAULT',
#   'weapon_primary': '07',
#   'weapon_description': 'CLUB',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.594, 36.032]}},
#  {'primary_key': '20220000149_11',
#   'incident_number': '20220000149',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-01T01:00:00.000',
#   'incident_reported': '2022-01-01T02:49:00.000',
#   'incident_location': 'RAINWOOD DR',
#   'latitude': '36.24',
#   'longitude': '-86.77',
#   'rpa': '2033',
#   'zone': '721',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '290',
#   'offense_description': 'DAMAGE PROP - PRIVATE',
#   'weapon_primary': '02',
#   'weapon_description': 'RIFLE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Unknown',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.77, 36.24]}},
#  {'primary_key': '20220000201_11',
#   'incident_number': '20220000201',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2021-12-31T23:30:00.000',
#   'incident_reported': '2022-01-01T02:51:00.000',
#   'incident_location': '33RD AVE N',
#   'latitude': '36.16',
#   'longitude': '-86.83',
#   'rpa': '4565',
#   'zone': '621',
#   'location_code': '13',
#   'location_description': 'HIGHWAY, ROAD, ALLEY',
#   'offense_number': '1',
#   'offense_nibrs': '290',
#   'offense_description': 'DAMAGE PROP - PRIVATE',
#   'weapon_primary': '07',
#   'weapon_description': 'CLUB',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.83, 36.16]}},
#  {'primary_key': '20220000201_21',
#   'incident_number': '20220000201',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2021-12-31T23:30:00.000',
#   'incident_reported': '2022-01-01T02:51:00.000',
#   'incident_location': '33RD AVE N',
#   'latitude': '36.16',
#   'longitude': '-86.83',
#   'rpa': '4565',
#   'zone': '621',
# ...
#   'incident_location': '3210 3210',
#   'latitude': '36.181',
#   'longitude': '-86.838',
#   'zip_code': '37218',
#   'rpa': '3173',
#   'zone': '625',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.838, 36.181]}},
#  {'primary_key': '20220004278_11',
#   'incident_number': '20220004278',
#   'report_type': 'O',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-17T18:00:00.000',
#   'incident_reported': '2022-01-04T07:13:00.000',
#   'incident_location': '1801 1801',
#   'latitude': '36.203',
#   'longitude': '-86.769',
#   'zip_code': '37207',
#   'rpa': '1861',
#   'zone': '223',
#   'location_code': '14',
#   'location_description': 'HOTEL, MOTEL, ETC.',
#   'offense_number': '1',
#   'offense_nibrs': '23D',
#   'offense_description': 'LARC - FROM BLDG',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.769, 36.203]}},
#  {'primary_key': '20220004322_11',
#   'incident_number': '20220004322',
#   'report_type': 'T',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-02T12:00:00.000',
#   'incident_reported': '2022-01-04T07:17:00.000',
#   'incident_location': 'OPRY MILLS DR',
#   'latitude': '36.2',
#   'longitude': '-86.69',
#   'rpa': '9209',
#   'zone': '515',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '23G',
#   'offense_description': 'LARC - PARTS FROM VEH',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.69, 36.2]}},
#  {'primary_key': '20220004284_11',
#   'incident_number': '20220004284',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'R',
#   'incident_status_description': 'REFUSED TO COOPERATE',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-01-04T06:45:00.000',
#   'incident_reported': '2022-01-04T07:21:00.000',
#   'incident_location': '2120 2120',
#   'latitude': '36.133',
#   'longitude': '-86.634',
#   'zip_code': '37214',
#   'rpa': '8991',
#   'zone': '533',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '13B',
#   'offense_description': 'SIMPLE ASSLT',
#   'weapon_primary': '09',
#   'weapon_description': 'PERSONAL (HANDS)',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.634, 36.133]}},
#  {'primary_key': '20220004303_11',
#   'incident_number': '20220004303',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-04T07:07:00.000',
#   'incident_reported': '2022-01-04T07:45:00.000',
#   'incident_location': '1028 1028',
#   'latitude': '36.259',
#   'longitude': '-86.68',
#   'zip_code': '37115',
#   'rpa': '1635',
#   'zone': '713',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'POLICE INQUIRY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': True,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.68, 36.259]}},
#  {'primary_key': '20220004321_11',
#   'incident_number': '20220004321',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-03T07:00:00.000',
#   'incident_reported': '2022-01-04T07:49:00.000',
#   'incident_location': '585 585',
#   'latitude': '36.283',
#   'longitude': '-86.796',
#   'zip_code': '37189',
#   'rpa': '2105',
#   'zone': '725',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '240',
#   'offense_description': 'VEHICLE THEFT',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.796, 36.283]}},
#  {'primary_key': '20220004336_12',
#   'incident_number': '20220004336',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-04T02:00:00.000',
#   'incident_reported': '2022-01-04T07:53:00.000',
#   'incident_location': 'WALLACE RD',
#   'latitude': '36.08',
#   'longitude': '-86.72',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '2',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.72, 36.08]}},
#  {'primary_key': '20220004336_11',
#   'incident_number': '20220004336',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-04T02:00:00.000',
#   'incident_reported': '2022-01-04T07:53:00.000',
#   'incident_location': 'WALLACE RD',
#   'latitude': '36.08',
#   'longitude': '-86.72',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '23F',
#   'offense_description': 'BURGLARY- MOTOR VEHICLE',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.72, 36.08]}},
#  {'primary_key': '20220004329_11',
#   'incident_number': '20220004329',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-04T07:24:00.000',
#   'incident_reported': '2022-01-04T08:11:00.000',
#   'incident_location': 'FRIST BLVD',
#   'latitude': '36.18',
#   'longitude': '-86.61',
#   'rpa': '9561',
#   'zone': '521',
#   'location_code': '9',
#   'location_description': 'HOSPITAL',
#   'offense_number': '1',
#   'offense_nibrs': '35A',
#   'offense_description': 'MARIJUANA - POSSESS',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'S',
#   'victim_description': 'SOCIETY',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.61, 36.18]}},
#  {'primary_key': '20220004430_11',
#   'incident_number': '20220004430',
#   'report_type': 'T',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2021-12-17T22:00:00.000',
#   'incident_reported': '2022-01-04T08:14:00.000',
#   'incident_location': 'E NOCTURNE DR',
#   'latitude': '36.21',
#   'longitude': '-86.79',
#   'rpa': '3039',
#   'zone': '633',
#   'location_code': '20',
#   'location_description': 'PARKING LOT, GARAGE',
#   'offense_number': '1',
#   'offense_nibrs': '23G',
#   'offense_description': 'LARC - PARTS FROM VEH',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'F',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.79, 36.21]}},
#  {'primary_key': '20220004264_11',
#   'incident_number': '20220004264',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2022-01-04T06:34:00.000',
#   'incident_reported': '2022-01-04T08:16:00.000',
#   'incident_location': '2112 2112',
#   'latitude': '36.157',
#   'longitude': '-86.807',
#   'zip_code': '37209',
#   'rpa': '5339',
#   'zone': '613',
#   'location_code': '25',
#   'location_description': 'SERVICE, GAS STATION',
#   'offense_number': '1',
#   'offense_nibrs': '740',
#   'offense_description': 'TRANSPORT',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.807, 36.157]}},
#  {'primary_key': '20220004401_11',
#   'incident_number': '20220004401',
#   'report_type': 'T',
#   'incident_status_code': 'U',
#   'incident_status_description': 'UNFOUNDED',
#   'investigation_status': 'Closed',
#   'incident_occurred': '2021-12-28T22:00:00.000',
#   'incident_reported': '2022-01-04T08:19:00.000',
#   'incident_location': '5770 5770',
#   'latitude': '36.173',
#   'longitude': '-86.602',
#   'zip_code': '37076',
#   'rpa': '9557',
#   'zone': '523',
#   'location_code': '23',
#   'location_description': 'RESTAURANT',
#   'offense_number': '1',
#   'offense_nibrs': '810',
#   'offense_description': 'LOST PROPERTY',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'B',
#   'victim_ethnicity': 'Non-Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.602, 36.173]}},
#  {'primary_key': '20220004368_11',
#   'incident_number': '20220004368',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-04T06:00:00.000',
#   'incident_reported': '2022-01-04T08:24:00.000',
#   'incident_location': 'BELL RD',
#   'latitude': '36.05',
#   'longitude': '-86.68',
#   'location_code': '22',
#   'location_description': 'RESIDENCE, HOME',
#   'offense_number': '1',
#   'offense_nibrs': '240',
#   'offense_description': 'VEHICLE THEFT',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'I',
#   'victim_description': 'INDIVIDUAL (18 AND OVER)',
#   'victim_gender': 'M',
#   'victim_race': 'W',
#   'victim_ethnicity': 'Hispanic',
#   'victim_county_resident': 'RESIDENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.68, 36.05]}},
#  {'primary_key': '20220004405_11',
#   'incident_number': '20220004405',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-04T07:35:00.000',
#   'incident_reported': '2022-01-04T08:30:00.000',
#   'incident_location': 'DICKERSON PIKE',
#   'latitude': '36.22',
#   'longitude': '-86.76',
#   'rpa': '1823',
#   'zone': '223',
#   'location_code': '25',
#   'location_description': 'SERVICE, GAS STATION',
#   'offense_number': '1',
#   'offense_nibrs': '290',
#   'offense_description': 'DAMAGE PROP - PRIVATE',
#   'weapon_primary': '16',
#   'weapon_description': 'Unarmed',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.76, 36.22]}},
#  {'primary_key': '20220004404_22',
#   'incident_number': '20220004404',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-04T01:30:00.000',
#   'incident_reported': '2022-01-04T08:40:00.000',
#   'incident_location': 'HAYWOOD LN',
#   'latitude': '36.07',
#   'longitude': '-86.69',
#   'location_code': '7',
#   'location_description': 'CONVENIENCE STORE',
#   'offense_number': '2',
#   'offense_nibrs': '250',
#   'offense_description': 'COUNTERFEIT LOGO - USE OR SELL- $1,000 OR LESS',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '2',
#   'domestic_related': False,
#   'victim_type': 'G',
#   'victim_description': 'GOVERNMENT',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.69, 36.07]}},
#  {'primary_key': '20220004404_11',
#   'incident_number': '20220004404',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2022-01-04T01:30:00.000',
#   'incident_reported': '2022-01-04T08:40:00.000',
#   'incident_location': 'HAYWOOD LN',
#   'latitude': '36.07',
#   'longitude': '-86.69',
#   'location_code': '7',
#   'location_description': 'CONVENIENCE STORE',
#   'offense_number': '1',
#   'offense_nibrs': '26A',
#   'offense_description': 'FRAUD, CRIMINAL ATTEMPT',
#   'weapon_primary': '17',
#   'weapon_description': 'NONE',
#   'victim_number': '1',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.69, 36.07]}},
#  {'primary_key': '20220004370_23',
#   'incident_number': '20220004370',
#   'report_type': 'D',
#   'report_type_description': 'DISPATCHED',
#   'incident_status_code': 'O',
#   'incident_status_description': 'OPEN',
#   'investigation_status': 'Open',
#   'incident_occurred': '2021-12-30T15:30:00.000',
#   'incident_reported': '2022-01-04T08:43:00.000',
#   'incident_location': 'MT VIEW RD',
#   'latitude': '36.05',
#   'longitude': '-86.65',
#   'location_code': '6',
#   'location_description': 'CONSTRUCTION SITE',
#   'offense_number': '2',
#   'offense_nibrs': '290',
#   'offense_description': 'DAMAGE PROP - BUSINESS',
#   'weapon_primary': '06',
#   'weapon_description': 'LETHAL/CUTTING INSTRUMENT',
#   'victim_number': '3',
#   'domestic_related': False,
#   'victim_type': 'B',
#   'victim_description': 'BUSINESS',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.65, 36.05]}}]

# %%
res_df = pd.DataFrame(offense_response.json()).head(10)
res_df
# Out:
#       primary_key incident_number report_type report_type_description  \
# 0  20171099391_21     20171099391           D              DISPATCHED
# 1  20190582775_11     20190582775           D              DISPATCHED
# 2  20190406807_11     20190406807           T                     NaN
# 3  20160236445_11     20160236445           D              DISPATCHED
# 4  20210073684_11     20210073684           D              DISPATCHED
# 5  20170901990_11     20170901990           D              DISPATCHED
# 6  20180585905_31     20180585905           D              DISPATCHED
# 7  20150202414_21     20150202414           D              DISPATCHED
# 8  20210077341_11     20210077341           S                 SUSPECT
# 9  20210249540_11     20210249540           D              DISPATCHED
#
#   incident_status_code incident_status_description investigation_status  \
# 0                    A           CLEARED BY ARREST               Closed
# 1                    A           CLEARED BY ARREST               Closed
# 2                    O                        OPEN                 Open
# 3                    A           CLEARED BY ARREST               Closed
# 4                    A           CLEARED BY ARREST               Closed
# 5                    O                        OPEN                 Open
# 6                    A           CLEARED BY ARREST               Closed
# 7                    A           CLEARED BY ARREST               Closed
# 8                    A           CLEARED BY ARREST               Closed
# 9                    O                        OPEN                 Open
#
#          incident_occurred        incident_reported incident_location  ...  \
# 0  2017-12-16T18:30:00.000  2017-12-16T22:44:00.000         1101 1101  ...
# 1  2019-08-05T23:08:00.000  2019-08-05T23:41:00.000         1726 1726  ...
# 2  2019-05-24T15:00:00.000  2019-05-28T09:27:00.000        CLIFTON LN  ...
# 3  2016-03-12T02:20:00.000  2016-03-12T03:31:00.000           142 142  ...
# 4  2021-02-06T14:41:00.000  2021-02-06T17:35:00.000           706 706  ...
# 5  2017-10-05T18:00:00.000  2017-10-12T13:27:00.000        DEL SOL DR  ...
# 6  2018-07-06T23:50:00.000  2018-07-07T01:43:00.000         2221 2221  ...
# 7  2015-03-01T03:10:00.000  2015-03-01T04:44:00.000         2418 2418  ...
# 8  2021-01-23T08:49:00.000  2021-02-08T12:25:00.000         3020 3020  ...
# 9  2021-05-04T23:45:00.000  2021-05-05T00:45:00.000     UNIVERSITY CT  ...
#
#   weapon_description victim_number domestic_related victim_type  \
# 0   PERSONAL (HANDS)             1             True           I
# 1               NONE             1            False           I
# 2               NONE             1            False           B
# 3   PERSONAL (HANDS)             1            False           I
# 4               CLUB             1            False           I
# 5               NONE             1            False           B
# 6   PERSONAL (HANDS)             1             True           I
# 7   PERSONAL (HANDS)             1            False           I
# 8               NONE             1             True           I
# 9   PERSONAL (HANDS)             1            False           I
#
#          victim_description victim_gender victim_race victim_ethnicity  \
# 0  INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# 1  INDIVIDUAL (18 AND OVER)             M           W     Non-Hispanic
# 2                  BUSINESS           NaN         NaN              NaN
# 3  INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# 4  INDIVIDUAL (18 AND OVER)             F           W     Non-Hispanic
# 5                  BUSINESS           NaN         NaN              NaN
# 6  INDIVIDUAL (18 AND OVER)             M           W     Non-Hispanic
# 7  INDIVIDUAL (18 AND OVER)             M           W     Non-Hispanic
# 8  INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# 9  INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
#
#   victim_county_resident                                    mapped_location
# 0               RESIDENT  {'type': 'Point', 'coordinates': [-86.586, 36....
# 1               RESIDENT  {'type': 'Point', 'coordinates': [-86.795, 36....
# 2                    NaN  {'type': 'Point', 'coordinates': [-86.79, 36.11]}
# 3               RESIDENT  {'type': 'Point', 'coordinates': [-86.674, 36....
# 4               RESIDENT  {'type': 'Point', 'coordinates': [-86.73, 36.12]}
# 5                    NaN  {'type': 'Point', 'coordinates': [-86.81, 36.24]}
# 6               RESIDENT  {'type': 'Point', 'coordinates': [-86.816, 36....
# 7               RESIDENT  {'type': 'Point', 'coordinates': [-86.74, 36.1...
# 8               RESIDENT  {'type': 'Point', 'coordinates': [-86.818, 36....
# 9               RESIDENT  {'type': 'Point', 'coordinates': [-86.77, 36.15]}
#
# [10 rows x 31 columns]

# %%
offense = "https://data.nashville.gov/resource/2u6v-ujjs.json?offense_description=BURGLARY- AGGRAVATED"
offense_response = requests.get(offense)

# %%
offense_response.text
# Out:
# '[{"primary_key":"20171099391_21","incident_number":"20171099391","report_type":"D","report_type_description":"DISPATCHED","incident_status_code":"A","incident_status_description":"CLEARED BY ARREST","investigation_status":"Closed","incident_occurred":"2017-12-16T18:30:00.000","incident_reported":"2017-12-16T22:44:00.000","incident_location":"1101 1101","latitude":"36.178","longitude":"-86.586","zip_code":"37076","rpa":"9539","zone":"523","location_code":"22","location_description":"RESIDENCE, HOME","offense_number":"2","offense_nibrs":"220","offense_description":"BURGLARY- AGGRAVATED","weapon_primary":"09","weapon_description":"PERSONAL (HANDS)","victim_number":"1","domestic_related":true,"victim_type":"I","victim_description":"INDIVIDUAL (18 AND OVER)","victim_gender":"F","victim_race":"B","victim_ethnicity":"Non-Hispanic","victim_county_resident":"RESIDENT","mapped_location":{"type":"Point","coordinates":[-86.586,36.178]}}\n,{"primary_key":"20190582775_11","incident_number":"20190582775","report_type":"D","report_type_description":"DISPATCHED","incident_status_code":"A","incident_status_description":"CLEARED BY ARREST","investigation_status":"Closed","incident_occurred":"2019-08-05T23:08:00.000","incident_reported":"2019-08-05T23:41:00.000","incident_location":"1726 1726","latitude":"36.182","longitude":"-86.795","zip_code":"37208","rpa":"4341","zone":"615","location_code":"22","location_description":"RESIDENCE, HOME","offense_number":"1","offense_nibrs":"220","offense_description":"BURGLARY- AGGRAVATED","weapon_primary":"17","weapon_description":"NONE","victim_number":"1","domestic_related":false,"victim_type":"I","victim_description":"INDIVIDUAL (18 AND OVER)","victim_gender":"M","victim_race":"W","victim_ethnicity":"Non-Hispanic","victim_county_resident":"RESIDENT","mapped_location":{"type":"Point","coordinates":[-86.795,36.182]}}\n,{"primary_key":"20190406807_11","incident_number":"20190406807","report_type":"T","incident_status_code":"O","incident_status_description":"OPEN","investigation_status":"Open","incident_occurred":"2019-05-24T15:00:00.000","incident_reported":"2019-05-28T09:27:00.000","incident_location":"CLIFTON LN","latitude":"36.11","longitude":"-86.79","rpa":"6417","zone":"821","location_code":"22","location_description":"RESIDENCE, HOME","offense_number":"1","offense_nibrs":"220","offense_description":"BURGLARY- AGGRAVATED","weapon_primary":"17","weapon_description":"NONE","victim_number":"1","domestic_related":false,"victim_type":"B","victim_description":"BUSINESS","mapped_location":{"type":"Point","coordinates":[-86.79,36.11]}}\n,{"primary_key":"20160236445_11","incident_number":"20160236445","report_type":"D","report_type_description":"DISPATCHED","incident_status_code":"A","incident_status_description":"CLEARED BY ARREST","investigation_status":"Closed","incident_occurred":"2016-03-12T02:20:00.000","incident_reported":"2016-03-12T03:31:00.000","incident_location":"142 142","latitude":"36.05","longitude":"-86.674","zip_code":"37013","rpa":"8719","zone":"331","location_code":"22","location_description":"RESIDENCE, HOME","offense_number":"1","offense_nibrs":"220","offense_description":"BURGLARY- AGGRAVATED","weapon_primary":"09","weapon_description":"PERSONAL (HANDS)","victim_number":"1","domestic_related":false,"victim_type":"I","victim_description":"INDIVIDUAL (18 AND OVER)","victim_gender":"F","victim_race":"B","victim_ethnicity":"Non-Hispanic","victim_county_resident":"RESIDENT","mapped_location":{"type":"Point","coordinates":[-86.674,36.05]}}\n,{"primary_key":"20210073684_11","incident_number":"20210073684","report_type":"D","report_type_description":"DISPATCHED","incident_status_code":"A","incident_status_description":"CLEARED BY ARREST","investigation_status":"Closed","incident_occurred":"2021-02-06T14:41:00.000","incident_reported":"2021-02-06T17:35:00.000","incident_location":"706 706","latitude":"36.12","longitude":"-86.73","zip_code":"37210","rpa":"8331","zone":"313","location_code":"22","loca ...

# %%
response_offense = pd.DataFrame(offense_response.json()).head(5)
response_offense
# Out:
#       primary_key incident_number report_type report_type_description  \
# 0  20171099391_21     20171099391           D              DISPATCHED
# 1  20190582775_11     20190582775           D              DISPATCHED
# 2  20190406807_11     20190406807           T                     NaN
# 3  20160236445_11     20160236445           D              DISPATCHED
# 4  20210073684_11     20210073684           D              DISPATCHED
#
#   incident_status_code incident_status_description investigation_status  \
# 0                    A           CLEARED BY ARREST               Closed
# 1                    A           CLEARED BY ARREST               Closed
# 2                    O                        OPEN                 Open
# 3                    A           CLEARED BY ARREST               Closed
# 4                    A           CLEARED BY ARREST               Closed
#
#          incident_occurred        incident_reported incident_location  ...  \
# 0  2017-12-16T18:30:00.000  2017-12-16T22:44:00.000         1101 1101  ...
# 1  2019-08-05T23:08:00.000  2019-08-05T23:41:00.000         1726 1726  ...
# 2  2019-05-24T15:00:00.000  2019-05-28T09:27:00.000        CLIFTON LN  ...
# 3  2016-03-12T02:20:00.000  2016-03-12T03:31:00.000           142 142  ...
# 4  2021-02-06T14:41:00.000  2021-02-06T17:35:00.000           706 706  ...
#
#   weapon_description victim_number domestic_related victim_type  \
# 0   PERSONAL (HANDS)             1             True           I
# 1               NONE             1            False           I
# 2               NONE             1            False           B
# 3   PERSONAL (HANDS)             1            False           I
# 4               CLUB             1            False           I
#
#          victim_description victim_gender victim_race victim_ethnicity  \
# 0  INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# 1  INDIVIDUAL (18 AND OVER)             M           W     Non-Hispanic
# 2                  BUSINESS           NaN         NaN              NaN
# 3  INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# 4  INDIVIDUAL (18 AND OVER)             F           W     Non-Hispanic
#
#   victim_county_resident                                    mapped_location
# 0               RESIDENT  {'type': 'Point', 'coordinates': [-86.586, 36....
# 1               RESIDENT  {'type': 'Point', 'coordinates': [-86.795, 36....
# 2                    NaN  {'type': 'Point', 'coordinates': [-86.79, 36.11]}
# 3               RESIDENT  {'type': 'Point', 'coordinates': [-86.674, 36....
# 4               RESIDENT  {'type': 'Point', 'coordinates': [-86.73, 36.12]}
#
# [5 rows x 31 columns]

# %%
BURGLARY = [res_df, response_offense]

# %%
result = pd.concat(BURGLARY)
display(result)
# Out:
#       primary_key incident_number report_type report_type_description  \
# 0  20171099391_21     20171099391           D              DISPATCHED
# 1  20190582775_11     20190582775           D              DISPATCHED
# 2  20190406807_11     20190406807           T                     NaN
# 3  20160236445_11     20160236445           D              DISPATCHED
# 4  20210073684_11     20210073684           D              DISPATCHED
# 5  20170901990_11     20170901990           D              DISPATCHED
# 6  20180585905_31     20180585905           D              DISPATCHED
# 7  20150202414_21     20150202414           D              DISPATCHED
# 8  20210077341_11     20210077341           S                 SUSPECT
# 9  20210249540_11     20210249540           D              DISPATCHED
# 0  20171099391_21     20171099391           D              DISPATCHED
# 1  20190582775_11     20190582775           D              DISPATCHED
# 2  20190406807_11     20190406807           T                     NaN
# 3  20160236445_11     20160236445           D              DISPATCHED
# 4  20210073684_11     20210073684           D              DISPATCHED
#
#   incident_status_code incident_status_description investigation_status  \
# 0                    A           CLEARED BY ARREST               Closed
# 1                    A           CLEARED BY ARREST               Closed
# 2                    O                        OPEN                 Open
# 3                    A           CLEARED BY ARREST               Closed
# 4                    A           CLEARED BY ARREST               Closed
# 5                    O                        OPEN                 Open
# 6                    A           CLEARED BY ARREST               Closed
# 7                    A           CLEARED BY ARREST               Closed
# 8                    A           CLEARED BY ARREST               Closed
# 9                    O                        OPEN                 Open
# 0                    A           CLEARED BY ARREST               Closed
# 1                    A           CLEARED BY ARREST               Closed
# 2                    O                        OPEN                 Open
# 3                    A           CLEARED BY ARREST               Closed
# 4                    A           CLEARED BY ARREST               Closed
#
#          incident_occurred        incident_reported incident_location  ...  \
# 0  2017-12-16T18:30:00.000  2017-12-16T22:44:00.000         1101 1101  ...
# 1  2019-08-05T23:08:00.000  2019-08-05T23:41:00.000         1726 1726  ...
# 2  2019-05-24T15:00:00.000  2019-05-28T09:27:00.000        CLIFTON LN  ...
# 3  2016-03-12T02:20:00.000  2016-03-12T03:31:00.000           142 142  ...
# 4  2021-02-06T14:41:00.000  2021-02-06T17:35:00.000           706 706  ...
# 5  2017-10-05T18:00:00.000  2017-10-12T13:27:00.000        DEL SOL DR  ...
# 6  2018-07-06T23:50:00.000  2018-07-07T01:43:00.000         2221 2221  ...
# 7  2015-03-01T03:10:00.000  2015-03-01T04:44:00.000         2418 2418  ...
# 8  2021-01-23T08:49:00.000  2021-02-08T12:25:00.000         3020 3020  ...
# 9  2021-05-04T23:45:00.000  2021-05-05T00:45:00.000     UNIVERSITY CT  ...
# 0  2017-12-16T18:30:00.000  2017-12-16T22:44:00.000         1101 1101  ...
# 1  2019-08-05T23:08:00.000  2019-08-05T23:41:00.000         1726 1726  ...
# 2  2019-05-24T15:00:00.000  2019-05-28T09:27:00.000        CLIFTON LN  ...
# 3  2016-03-12T02:20:00.000  2016-03-12T03:31:00.000           142 142  ...
# 4  2021-02-06T14:41:00.000  2021-02-06T17:35:00.000           706 706  ...
#
#   weapon_description victim_number domestic_related victim_type  \
# 0   PERSONAL (HANDS)             1             True           I
# 1               NONE             1            False           I
# 2               NONE             1            False           B
# 3   PERSONAL (HANDS)             1            False           I
# 4               CLUB             1            False           I
# 5               NONE             1            False           B
# 6   PERSONAL (HANDS)             1             True           I
# 7   PERSONAL (HANDS)             1            False           I
# 8               NONE             1             True           I
# 9   PERSONAL (HANDS)             1            False           I
# 0   PERSONAL (HANDS)             1             True           I
# 1               NONE             1            False           I
# 2               NONE             1            False           B
# 3   PERSONAL (HANDS)             1            False           I
# 4               CLUB             1            False           I
#
#          victim_description victim_gender victim_race victim_ethnicity  \
# 0  INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# 1  INDIVIDUAL (18 AND OVER)             M           W     Non-Hispanic
# 2                  BUSINESS           NaN         NaN              NaN
# 3  INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# 4  INDIVIDUAL (18 AND OVER)             F           W     Non-Hispanic
# 5                  BUSINESS           NaN         NaN              NaN
# 6  INDIVIDUAL (18 AND OVER)             M           W     Non-Hispanic
# 7  INDIVIDUAL (18 AND OVER)             M           W     Non-Hispanic
# 8  INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# 9  INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# 0  INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# 1  INDIVIDUAL (18 AND OVER)             M           W     Non-Hispanic
# 2                  BUSINESS           NaN         NaN              NaN
# 3  INDIVIDUAL (18 AND OVER)             F           B     Non-Hispanic
# 4  INDIVIDUAL (18 AND OVER)             F           W     Non-Hispanic
#
#   victim_county_resident                                    mapped_location
# 0               RESIDENT  {'type': 'Point', 'coordinates': [-86.586, 36....
# 1               RESIDENT  {'type': 'Point', 'coordinates': [-86.795, 36....
# 2                    NaN  {'type': 'Point', 'coordinates': [-86.79, 36.11]}
# 3               RESIDENT  {'type': 'Point', 'coordinates': [-86.674, 36....
# 4               RESIDENT  {'type': 'Point', 'coordinates': [-86.73, 36.12]}
# 5                    NaN  {'type': 'Point', 'coordinates': [-86.81, 36.24]}
# 6               RESIDENT  {'type': 'Point', 'coordinates': [-86.816, 36....
# 7               RESIDENT  {'type': 'Point', 'coordinates': [-86.74, 36.1...
# 8               RESIDENT  {'type': 'Point', 'coordinates': [-86.818, 36....
# 9               RESIDENT  {'type': 'Point', 'coordinates': [-86.77, 36.15]}
# 0               RESIDENT  {'type': 'Point', 'coordinates': [-86.586, 36....
# 1               RESIDENT  {'type': 'Point', 'coordinates': [-86.795, 36....
# 2                    NaN  {'type': 'Point', 'coordinates': [-86.79, 36.11]}
# 3               RESIDENT  {'type': 'Point', 'coordinates': [-86.674, 36....
# 4               RESIDENT  {'type': 'Point', 'coordinates': [-86.73, 36.12]}
#
# [15 rows x 31 columns]
